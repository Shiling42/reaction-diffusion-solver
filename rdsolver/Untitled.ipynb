# %%
from reaction_diffu import *

# %%
sys1=RDSystem([Reactant(0.05)],init_dis= 'gaussian')

# %%
t=np.linspace(0,2,1000)
dis = sys1.integrate(t)
#plt.plot(t,dis[:,0])
plt.plot(dis[100])

# %%
dis[-1]
# Out:
# array([ 0.4915815 ,  0.49162841,  0.49172149,  0.49185928,  0.49203959,
#         0.4922596 ,  0.49251582,  0.49280421,  0.49312023,  0.4934589 ,
#         0.49381487,  0.49418253,  0.49455608,  0.49492963,  0.49529729,
#         0.49565326,  0.49599193,  0.49630795,  0.49659634,  0.49685256,
#         0.49707256,  0.49725288,  0.49739066,  0.49748374,  0.49753065,
#         0.49753065,  0.49748374,  0.49739066,  0.49725288,  0.49707256,
#         0.49685256,  0.49659634,  0.49630795,  0.49599193,  0.49565326,
#         0.49529729,  0.49492963,  0.49455608,  0.49418253,  0.49381487,
#         0.4934589 ,  0.49312023,  0.49280421,  0.49251582,  0.4922596 ,
#         0.49203959,  0.49185928,  0.49172149,  0.49162841,  0.4915815 ])

# %%
plt.plot(dis[999])

# %%
sys1.dis
# Out:
# array([[ 0.4915815 ,  0.49162841,  0.49172149,  0.49185928,  0.49203959,
#          0.4922596 ,  0.49251582,  0.49280421,  0.49312023,  0.4934589 ,
#          0.49381487,  0.49418253,  0.49455608,  0.49492963,  0.49529729,
#          0.49565326,  0.49599193,  0.49630795,  0.49659634,  0.49685256,
#          0.49707256,  0.49725288,  0.49739066,  0.49748374,  0.49753065,
#          0.49753065,  0.49748374,  0.49739066,  0.49725288,  0.49707256,
#          0.49685256,  0.49659634,  0.49630795,  0.49599193,  0.49565326,
#          0.49529729,  0.49492963,  0.49455608,  0.49418253,  0.49381487,
#          0.4934589 ,  0.49312023,  0.49280421,  0.49251582,  0.4922596 ,
#          0.49203959,  0.49185928,  0.49172149,  0.49162841,  0.4915815 ]])

# %%
from turing_pattern import *
import time

start_time = time.time()
Turing_1 = TuringPattern(space_size = 30)
#Turing_1.stationary()
t=np.linspace(0,10,2)
Turing_1.integrate(t)
plt.imshow(Turing_1.dis[0])
plt.show()

print(time.time() - start_time)
# Out:
# 12.213303565979004

# %%
from turing_pattern import *
import time

start_time = time.time()
Turing_1 = TuringPattern(space_size = 500)
#Turing_1.stationary()

Turing_1.evolve(10)
plt.imshow(Turing_1.dis[0])
plt.show()


print(time.time() - start_time)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-3b7f8c5d667e> in <module>
#       6 #Turing_1.stationary()
#       7
# ----> 8 Turing_1.evolve(10)
#       9 plt.imshow(Turing_1.dis[0])
#      10 plt.show()
#
# ~\Documents\GitHub\reaction-diffusion-solver\rdsolver\reaction_diffu.py in evolve(self, evolve_time, print_time)
#     102         i=0
#     103         for i in range(int(evolve_time/self.dt)):
# --> 104             self.diffusion_reaction();
#     105             if i%10000 ==0:
#     106                 print('dt: ',i*self.dt) if print_time == True else None
#
# ~\Documents\GitHub\reaction-diffusion-solver\rdsolver\reaction_diffu.py in diffusion_reaction(self)
#      96
#      97     def diffusion_reaction(self):
# ---> 98         self.dis += (self.diffusion()+self.reaction()+self.noise()/np.sqrt(self.dt))*self.dt;
#      99
#     100
#
# ...

# %%
#fig, ax=plt.plot()
plt.imshow(Turing_1.dis[0])
plt.axis('off')
plt.imsave('turing.png',Turing_1.dis[0])
