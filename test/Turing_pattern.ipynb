# %%
import sys
sys.path.append('..')


#from rdsolver import turing_pattern as tNp
#dir(rds)
from rdsolver.turing_pattern import *

# %%
Turing_1 = TuringPattern()
#Turing_1.stationary()
t=np.linspace(0,10,1000)
Turing_1.integrate(t)
plt.imshow(Turing_1.dis[0])
plt.show()

# %%
Turing_1 = TuringPattern(space_size=100)
for i in range(10):
    Turing_1.evolve(2)
    plt.imshow(Turing_1.dis[0])
    plt.show()
