# %%
import sys
sys.path.append('..')


#from rdsolver import turing_pattern as tNp
#dir(rds)
from rdsolver.two_components import *

# %%
sys1=RDSystem([Reactant(0.05)],init_dis= 'gaussian')

# %%
t=np.linspace(0,2,1000)
dis = sys1.integrate(t)
#plt.plot(t,dis[:,0])
plt.plot(dis[100])

# %%
plt.plot(dis[999])

# %%
from rdsolver.turing_pattern import *
import time

start_time = time.time()
Turing_1 = TuringPattern(space_size = 30)
#Turing_1.stationary()
t=np.linspace(0,10,2)
Turing_1.integrate(t)
plt.imshow(Turing_1.dis[0])
plt.show()

print(time.time() - start_time)
# Out:
# 3.6515939235687256
