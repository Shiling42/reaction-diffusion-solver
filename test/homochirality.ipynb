# %% [markdown]
# # Homochirality reaction-diffusion

# %%
import sys
sys.path.append('..')


#from rdsolver import turing_pattern as tNp
#dir(rds)
from rdsolver.reaction_diffu import *

# %% [markdown]
# ## Define the model

# %%
class ABC_Selection(RDSystem):
    def __init__(self,
                 Db = 2e-2, Dc =1e-2,
                 kab = 1e-5,
                 kba = 3e-4,
                 kac = 1e-5,
                 kca = 3e-4,
                 phi = 1e-1,
                 a0 = 20,
                 space_size = 30,dim = 2,
                 dt=0.01,
                 boundary = 'periodic',
                 init_dis= 'random',
                 init_boundary = False,
                 *args):
        self.kab, self.kba, self.kac ,self.kca, self.phi, self.a0 = (kab, kba, kac, kca, phi, a0)
        Reactant1 = Reactant(Db)
        Reactant2 = Reactant(Dc)
        reactants = [Reactant1,Reactant2]
        RDSystem.__init__(
        self,reactants,
        space_size =space_size, 
        init_dis = init_dis ,
        boundary = boundary, dim=dim,dt=dt)
        self.dx = 1
        self.dis[0,:,:] = np.random.random_sample(self.dis[0,:,:].shape)
        self.dis[1,:,:] = np.random.random_sample(self.dis[1,:,:].shape)
        if init_boundary == True:
            self.dis[0,:,:] = a0/2  
            self.dis[0,round(4*space_size/9):round(6*space_size/9),round(4*space_size/9):round(6*space_size/9)] = 0
            self.dis[1,:,:] = a0/2
            self.dis[1,round(4*space_size/9):round(6*space_size/9),round(4*space_size/9):round(6*space_size/9)] = a0*0.7
            #self.dis = self.dis*a0
            #self.dis[1] = self.dis[1]
        
    def reaction(self):
        u = self.dis
        dudt_reac = np.zeros(np.shape(self.dis))      
        if self.dim==2: #2D 
            dudt_reac[0,:,:] += self.kba * (self.a0-u[0]-u[1]) * u[0]**2 - self.kab * u[0]**3 - self.phi * u[0]
            dudt_reac[1,:,:] += self.kca * (self.a0-u[0]-u[1]) * u[1]**2 - self.kac * u[1]**3 - self.phi * u[1]
        return dudt_reac

# %% [markdown]
# ## Competing and co-existance

# %% [markdown]
# initilize as follows
# ```
# self.dis[0,:,:] = a0/3
# self.dis[1,:,:] = 0     self.dis[1,round(4*space_size/9):round(6*space_size/9),round(4*space_size/9):round(6*space_size/9)] = a0/2
# ```

# %%
ABC = ABC_Selection(
                 Db = 1e-1, Dc =10e-1,
                 kab = 1e-2,
                 kba = 3e-1,
                 kac = 1e-2,
                 kca = 3e-1,
                 phi = 2,
                 a0 = 20,
                 init_boundary = True)
#Turing_1.stationary()
t=np.linspace(0,50,1000)
time_series = ABC.integrate(t);

# %%
for times in [0,1,30,100,200,500,999]:
    fig, (ax1,ax2) = plt.subplots(figsize = (16,7), nrows=1, ncols=2)
    p1 = ax1.imshow(time_series[times].reshape((2,30,30))[0,:,:])
    #ax1.colorbar()
    fig.colorbar(p1, ax=ax1)
    p2 = ax2.imshow(time_series[times].reshape((2,30,30))[1,:,:])
    fig.colorbar(p2, ax=ax2)
    #fig.colorbar()
    plt.show()

# %% [markdown]
# ##  Random initialized state and two-stable state parameters gives co-existance pattern

# %%
ABC = ABC_Selection(
                 Db = 1e-2, Dc =1e-2,
                 kab = 1e-1,
                 kba = 1e0,
                 kac = 1e-1,
                 kca = 1e0,
                 phi = np.exp(-3.6),
                 a0 = 1,space_size = 50,
                 boundary = 'periodic',
                 init_boundary = False)
#Turing_1.stationary()
t=np.linspace(0,2000,1000)
time_series = ABC.integrate(t);

# %%
 
    #fig.colorbar()
    plt.show()
